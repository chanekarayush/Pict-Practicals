# %%
import re
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /home/ayush/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/ayush/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/ayush/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# ### 1. Load data

# %%
CSV_PATH = "./twitter_data.csv"
TEXT_COL = "Tweet"

df = pd.read_csv(CSV_PATH)
assert TEXT_COL in df.columns, f"Column '{TEXT_COL}' not found. Available: {list(df.columns)}"
print("Rows:", len(df))
print(df[[TEXT_COL]].head())
# Out:
# Rows: 74681
#                                                Tweet
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %% [markdown]
# ### 2. Pre-processing

# %%
stop_words = set(stopwords.words("english"))
lemm = WordNetLemmatizer()

def clean_tweet(s):
    s = str(s)
    s = s.lower()
    s = re.sub(r"http\S+", " ", s)     # URLs
    s = re.sub(r"@\w+", " ", s)        # mentions
    s = re.sub(r"#\w+", " ", s)        # hashtags (remove the token; keep word if you prefer)
    s = re.sub(r"&amp;", " and ", s)   # HTML entity
    s = re.sub(r"[^a-z\s]", " ", s)    # keep only letters and spaces
    s = re.sub(r"\s+", " ", s).strip()
    return s

def tokenize_lemmatize(s):
    toks = s.split()
    toks = [t for t in toks if t not in stop_words and len(t) > 2]  # drop stopwords/short tokens
    toks = [lemm.lemmatize(t) for t in toks]
    return toks

df["clean"] = df[TEXT_COL].apply(clean_tweet)
df["tokens"] = df["clean"].apply(tokenize_lemmatize)

# %%
print("Example tokens:", df["tokens"].head(3).tolist())
# Out:
# Example tokens: [['coming', 'border', 'kill'], ['getting', 'borderland', 'kill'], ['coming', 'borderland', 'murder']]

# %% [markdown]
# ### 3. Basic EDA

# %% [markdown]
# #### 3.1 Corpus-level Stats

# %%
all_tokens = [t for toks in df["tokens"] for t in toks]
num_docs = len(df)
num_tokens = len(all_tokens)
vocab = set(all_tokens)
vocab_size = len(vocab)

print(f"Documents: {num_docs}")
print(f"Total tokens: {num_tokens}")
print(f"Vocabulary size: {vocab_size}")
# Out:
# Documents: 74681
# Total tokens: 755907
# Vocabulary size: 26139

# %%
freqs = Counter(all_tokens)
print("Top 25 words:", freqs.most_common(25))
# Out:
# Top 25 words: [('game', 11011), ('com', 10059), ('like', 5007), ('get', 4383), ('pic', 4290), ('twitter', 4206), ('one', 3772), ('play', 3679), ('good', 3587), ('time', 3559), ('love', 3353), ('new', 3281), ('really', 3269), ('unk', 3113), ('johnson', 3041), ('people', 2942), ('shit', 2826), ('see', 2805), ('player', 2658), ('best', 2579), ('still', 2469), ('facebook', 2424), ('year', 2418), ('day', 2345), ('got', 2319)]

# %% [markdown]
# ### 4. Zipf's Law (rank–frequency)

# %% [markdown]
# #### 4.1. rank words by frequency

# %%
sorted_items = freqs.most_common()
ranks = np.arange(1, len(sorted_items) + 1)
freq_values = np.array([f for _, f in sorted_items], dtype=float)

# %% [markdown]
# #### 4.2. log-log

# %%
log_ranks = np.log(ranks)
log_freqs = np.log(freq_values)

# %% [markdown]
# #### 4.3. Linear fit on log-log to estimate slope (~ -1 for Zipf)

# %%
slope, intercept = np.polyfit(log_ranks, log_freqs, 1)
print(f"Zipf log-log fit: slope={slope:.3f}, intercept={intercept:.3f}")
# Out:
# Zipf log-log fit: slope=-1.394, intercept=14.449

# %% [markdown]
# #### 4.4. Plot

# %%
plt.figure()
plt.scatter(log_ranks, log_freqs, s=8)
plt.plot(log_ranks, slope*log_ranks + intercept)
plt.xlabel("log(rank)")
plt.ylabel("log(frequency)")
plt.title("Zipf's Law (rank–frequency, log–log)")
plt.show()

# %% [markdown]
# ### 5. Heaps' Law (vocabulary growth)
# > V(N) ~ k * N^β
# #### Sweep through corpus and record vocab size vs tokens

# %%
seen = set()
v_sizes = []
n_tokens_progress = []
count = 0
for toks in df["tokens"]:
    for t in toks:
        count += 1
        seen.add(t)
        if count % 500 == 0:  # sample every 500 tokens to speed up
            n_tokens_progress.append(count)
            v_sizes.append(len(seen))

# %% [markdown]
# > #### Fit log(V) = log(k) + β * log(N)

# %%
logN = np.log(np.array(n_tokens_progress, dtype=float))
logV = np.log(np.array(v_sizes, dtype=float))
beta, logk = np.polyfit(logN, logV, 1)
k = math.exp(logk)
print(f"Heaps parameters: k={k:.3f}, beta={beta:.3f}")
# Out:
# Heaps parameters: k=4.058, beta=0.649

# %% [markdown]
# #### Plot Heaps (linear)

# %%
plt.figure()
plt.plot(n_tokens_progress, v_sizes)
plt.xlabel("Tokens (N)")
plt.ylabel("Vocabulary size (V)")
plt.title("Heaps' Law (vocabulary growth)")
plt.show()

# %% [markdown]
# #### Plot Heaps (log–log)

# %%
plt.figure()
plt.scatter(logN, logV, s=10)
plt.plot(logN, beta*logN + logk)
plt.xlabel("log(N)")
plt.ylabel("log(V)")
plt.title("Heaps' Law (log–log)")
plt.show()

# %% [markdown]
# ### 6. Topic Identification (LDA)
# #### We’ll join tokens to strings to control preprocessing we already did.

# %%
docs_clean = df["tokens"].apply(lambda toks: " ".join(toks)).tolist()

vectorizer = CountVectorizer(
    max_features=10000,
    min_df=5,            # ignore very rare terms
    max_df=0.5           # ignore overly common terms
)

# %%
X = vectorizer.fit_transform(docs_clean)

# %% [markdown]
# #### 6.1. Fit LDA

# %%
N_TOPICS = 10      # adjust as needed
N_TOP_WORDS = 12   # words per topic to display

lda = LatentDirichletAllocation(
    n_components=N_TOPICS,
    random_state=42,
    learning_method="batch",
)
lda.fit(X)
# Out:
# LatentDirichletAllocation(random_state=42)

# %%
terms = np.array(vectorizer.get_feature_names_out())

# %%
def print_topics(model, terms, n_top_words=12):
    for i, comp in enumerate(model.components_):
        top_idx = np.argsort(comp)[::-1][:n_top_words]
        print(f"\nTopic {i:02d}:")
        print(", ".join(terms[top_idx]))

# %%
print_topics(lda, terms, n_top_words=N_TOP_WORDS)
# Out:
# Topic 00:
# com, microsoft, verizon, xbox, dead, red, nvidia, playstation, series, news, store, amazon
#
# Topic 01:
# johnson, pubg, baby, com, powder, vaccine, banned, covid, based, company, talc, news
#
# Topic 02:
# game, like, really, assassin, look, creed, new, good, feel, think, even, make
#
# Topic 03:
# call, people, facebook, duty, get, fucking, gta, account, like, know, really, would
#
# Topic 04:
# player, battlefield, ban, com, see, war, world, black, access, nan, health, care
#
# Topic 05:
# shit, fuck, home, unk, google, depot, like, com, amazon, facebook, buy, good
#
# Topic 06:
# pic, com, twitter, rhandlerr, team, year, got, like, one, best, day, hearthstone
#
# Topic 07:
# game, get, fix, ever, play, please, server, year, dead, one, still, time
#
# Topic 08:
# com, best, italy, facebook, twitter, please, dota, love, pic, youtube, borderland, moment
#
# Topic 09:
# time, play, twitch, legend, league, good, great, fun, thanks, stream, live, playing

# %% [markdown]
# ### 7. Topic distribution for a few documents

# %%
topic_dist = lda.transform(X)
print("\nDoc → top topic (first 5):")
for i, row in enumerate(topic_dist[:5]):
    print(i, np.argmax(row), f"(strength={row.max():.3f})")
# Out:
# Doc → top topic (first 5):
# 0 9 (strength=0.403)
# 1 7 (strength=0.775)
# 2 8 (strength=0.428)
# 3 8 (strength=0.528)
# 4 8 (strength=0.528)
